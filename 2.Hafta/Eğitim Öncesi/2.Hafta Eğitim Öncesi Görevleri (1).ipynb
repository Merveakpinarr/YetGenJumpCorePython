# %% [markdown]
# ### Soru 1
# Yazılımcıların bir dili öğrenmeye başladığında ilk yapacakları şey ekrana "Hello World" yazdırmaktır. Python'da da aynı şeyi yapalım.Bir yazılımcı aşağıdaki kodu yazarken hata yapıyor. Bunu düzelterek çalışan bir kod yazalım.

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Soru 2
# İki YetGen'li zirvede karşılaşıyor. Zirvede birbirleriyle Python standında konuşurken YetGen Jump Python renginin ne olduğunu konuşurken bir YetGen lideri **logo** değişkenine atayıp ekrana bastırmalarını istiyor. Onlara bu noktada yardımcı olur musun?

# %%
#logo = "kırmızı, mavi, sarı"
#print(logo)

print("yetgen'in logosunun rengi mavidir.")
# Out:
# yetgen'in logosunun rengi mavidir.

# %% [markdown]
# ### Soru 3
# Dairenin alanını hesaplayan bir Python kodu yazınız. pi sayısını 3.14 olarak alınız ve yarıçapını kullanıcıdan alınız. Sonucu ekrana bastırınız.

# %%
pi=3.14
diamenter = int(input("Dairenin çapını giriniz: "))
radius = diamenter/2
area = pi * radius ** 2
print(area)
# Out:
# 19.625

# %% [markdown]
# ### Soru 4
# x ve y adında iki liste oluşturunuz. Bu listeleri birbiryle yer değiştirerek yazdırınız.
#
# ```python
# x = [1,2,3,4,5]
# y = [5,4,3,2,1]
# ```
#
# ```python
# Output:
# x = [5, 4, 3, 2, 1]
# y = [1, 2, 3, 4, 5]
# ```

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 y = int(input("degiskenler "))
#       2 x = int(input("degiskenler"))
#       4 print(x,y)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1182, in Kernel.raw_input(self, prompt)
#    1180     msg = "raw_input was called, but this frontend does not support input requests."
#    1181     raise StdinNotImplementedError(msg)
# -> 1182 return self._input_request(
#    1183     str(prompt),
#    1184     self._parent_ident["shell"],
#    1185     self.get_parent("shell"),
#    1186     password=False,
#    1187 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1225, in Kernel._input_request(self, prompt, ident, parent, password)
#    1222 except KeyboardInterrupt:
#    1223     # re-raise KeyboardInterrupt, to truncate traceback
#    1224     msg = "Interrupted by user"
# -> 1225     raise KeyboardInterrupt(msg) from None
#    1226 except Exception:
#    1227     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Soru 5
# Aşağıda verilen kod satırının sonuncunu 1 olacak şekilde düzenleyiniz.

# %%
a = int(input("Birinci sayiyiyi giriniz: "))
b = int(input("İkinci sayiyiyi giriniz: "))
c = int(input("Üçüncü sayiyiyi giriniz: "))

print(a - b % c)
# Out:
# 4

# %% [markdown]
# ### Soru 6
# Aşağıdaki kod satırının sonuncusunu 0 olacak şekilde düzenleyiniz.

# %%
8 - 3 * 2 - 1 + 1
a = int(input("Birinci sayiyiyi giriniz: "))
b = int(input("İkinci sayiyiyi giriniz: "))
c = int(input("Üçüncü sayiyiyi giriniz: "))
d = int(input("dördüncü sayiyiyi giriniz: "))

print(a-b*c-d-d)
# Out:
# 0

# %% [markdown]
# ### Soru 7
# YetGen liderlerinden Berkcan, Emirhan ve Eslem, Ramazan Bayramı'nda topladıkları şekerlerini bir araya getirmeyi ve kendi aralarında eşit olarak paylaşmayı kabul ettiler.
# Eşit paylaşım yapıldıktan sonra kalan şekerler parçalanacak. Örneğin, eğer toplamda 91 şekerleri varsa , her biri 30 tane alıp kalan 1 tane şekeri parçalayacaklar.
# Kaç tane şekeri parçalayacaklarını hesaplayan bir Python kodu yazınız.

# %%
Sekersayısı = int(input("kaç adet şekeriniz var: "))
ParcalananSekersayısı = Sekersayısı % 3
print(ParcalananSekersayısı)
# eğer / kullanırsam float değerleri buluyorum, // int buluyorum
# % kalanı vermek için kullanıyorum.
# Out:
# 1
