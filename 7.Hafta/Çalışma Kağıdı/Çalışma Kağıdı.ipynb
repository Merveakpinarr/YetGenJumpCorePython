# %% [markdown]
# # Problem 1 Aradaki Tam Sayılar
#
# Kullanıcıdan iki adet sayı alınız, bu sayılar arasındaki tam sayıları ekrana yazdıran bir program yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
baslangic = int(input("Başlangıç sayısını girin: "))
bitis = int(input("Bitiş sayısını girin: "))

for sayi in range(baslangic, bitis + 1):
    print(sayi)

# %% [markdown]
# # Problem 2 Faktöriyel
#
# Kullanıcıdan bir sayı alınız ve alınan sayının faktöriyelini hesaplayan bir program yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
sayi = int(input("Bir sayı girin: "))

faktoriyel = 1
for i in range(1, sayi + 1):
    faktoriyel *= i

print("Faktöriyel:", faktoriyel)
# Out:
# Faktöriyel: 3628800

# %% [markdown]
# # Problem 3 Virgül ile Ayırma
#
# Kullanıcıdan bir metin halinde virgül ile ayrılmış sayılar alınız ve aldığınız her bir sayıyı listeye atayınız, daha sonra listedeki her elemanı toplayıp ekrana bastıran bir program yazınız.
#
# <h4>Sample Input</h4>
# <p>
# Lutfen sayilari virgul ile ayrirarak giriniz: 5,14,7,2,1
# </p>
# <h4>Output</h4>
#
# Toplam: 29

# %%
# 3.Problemin Çözümünü Buraya Yazınız

sayilar = input("Lütfen sayıları virgül ile ayırarak giriniz: ")
sayilar_listesi = sayilar.split(",")
toplam = sum([int(sayi) for sayi in sayilar_listesi])

print("Toplam:", toplam)
# Out:
# Toplam: 29

# %% [markdown]
# # Problem 4 Büyük Sayı
#
# Kullanıcıdan alınan iki sayıdan büyük olanı bulup, ekrana yazdıran bir fonksiyon yazınız.

# %%
# 4.Problemin Çözümünü Buraya Yazınız
def buyuk_sayi_bul(sayi1, sayi2):
    if sayi1 > sayi2:
        return sayi1
    else:
        return sayi2

# Kullanıcıdan sayıları alalım
sayi1 = int(input("Birinci sayıyı girin: "))
sayi2 = int(input("İkinci sayıyı girin: "))

# Büyük sayıyı bulup ekrana yazdıralım
buyuk_sayi = buyuk_sayi_bul(sayi1, sayi2)
print("Büyük sayı:", buyuk_sayi)
# Out:
# Büyük sayı: 20

# %% [markdown]
# # Problem 5 Ürün Kayıt Uygulaması
# Programımız ilk olarak kullanıcıdan, kaydı yapılacak ürünlerin sayısını isteyecek. Ardından yazılmış olan ürün sayısı kadar ürün ismi ve ürün fiyatı bilgisini kullanıcıdan alacak. Son olarak ise ürünleri ekrana yazdıracağız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen kac adet urun gireceginizi yaziniz: 3
# <br/>
# 1. Urununuzun ismini giriniz: Mentos
# <br/>
# 1. Urununuzun fiyatini giriniz: 1
# <br/>
# 2. Urununuzun ismini giriniz: Meybuz
# <br/>
# 2. Urununuzun fiyatini giriniz: 0.25
# <br/>
# 3. Urununuzun ismini giriniz: Uzun Şeker
# <br/>
# 3. Urununuzun fiyatini giriniz: 0.75
# <br/>
# <h4>Output:</h4>
# 1. Urun: Mentos - 1 TL
# <br/>
# 2. Urun: Meybuz - 0.25 TL
# <br/>
# 3. Urun: Uzun Şeker - 0.75 TL
# </p>

# %%
# 5.Problemin Çözümünü Buraya Yazınız

urun_sayisi = int(input("Lutfen kac adet urun gireceginizi yaziniz: "))

urunler = []
for i in range(urun_sayisi):
    urun_adi = input(f"{i+1}. Urununuzun ismini giriniz: ")
    urun_fiyati = input(f"{i+1}. Urununuzun fiyatini giriniz: ")
    urunler.append((urun_adi, urun_fiyati))

print("Output:")
for i, urun in enumerate(urunler):
    urun_adi, urun_fiyati = urun
    print(f"{i+1}. Urun: {urun_adi} - {urun_fiyati} TL")
# Out:
# Output:
# 1. Urun: Mentos - 1 TL
# 2. Urun: Meybuz - 0.25 TL
# 3. Urun: Uzun Şeker - 0.75 TL

# %% [markdown]
# # Problem 6 Türkçe Karakter Çevirici
# Programa girilen dosya ismindeki Türkçe karakterleri, İngilizce'ye çeviren programı yazınız.
#
# <h4>Sample Input:</h4>
# <p>
# Lutfen dosya ismi giriniz: fotoğraf.jpeg
# <br>
# Dosya ismi: fotograf.jpeg
# <br>
# <br>
# Lutfen dosya ismi giriniz: ışık.png
# <br>
# Dosya ismi: isik.png
# </p>

# %%
# 6.Problemin Çözümünü Buraya Yazınız
def turkce_karakter_cevirici(dosya_ismi):
    turkce_karakterler = "çÇğĞıİöÖşŞüÜ"
    ingilizce_karakterler = "cCgGiIoOsSuU"

    for i in range(len(turkce_karakterler)):
        dosya_ismi = dosya_ismi.replace(turkce_karakterler[i], ingilizce_karakterler[i])

    return dosya_ismi

dosya_ismi = input("Lutfen dosya ismi giriniz: ")
cevrilmis_dosya_ismi = turkce_karakter_cevirici(dosya_ismi)
print("Dosya ismi:", cevrilmis_dosya_ismi)
# Out:
# Dosya ismi: fotograj.jpeg

# %% [markdown]
# # Problem 7 Sayı Tahmin Oyunu ama Bilgisayar Tahmin Ediyor :)
# Sayı tahmin oyunu: İki oyuncudan birinin, 0 ile 100 arasında bir sayı tutması ile başlar. Diğer oyuncu ise tahminler yaparak tutulan sayıyı bulmaya çalışır ve yaptığı her tahminde sayıyı tutmuş olan oyuncudan YUKARI veya AŞAĞI olarak geri bildirim alır. Sayıyı bildiğinde ise rakip oyuncu kaç tahminde (kaç denemede) bildiğini söyler.
#
# Senden yazmanı beklediğimiz program ise Python'ın tahminleri yapan tarafta olacağı bir oyun oluşturman. Yani sen 0 ile 100 arasında bir sayı tutacaksın ardından program senin tuttuğunuz sayıyı bulmaya çalışacak.
# <h4>Sample Input:</h4>
# Bu örnekte aklınızdan 90 tuttuğunuzu varsayalım.
# <p>
# Oyun başlıyor lutfen aklindan bir sayi tut! Tuttun mu, hazır mısın? : 1
# <br>
# Tahmin: 50
# <br>
# Durum: Yukari
# <br>
# Tahmin: 75
# <br>
# Durum: Yukari
# <br>
# Tahmin: 87
# <br>
# Durum: Yukari
# <br>
# Tahmin: 93
# <br>
# Durum: Asagi
# <br>
# Tahmin: 90
# <br>
# Durum: Bildin
# </p>

# %%
# 7.Problemin Çözümünü Buraya Yazınız
import random

print("Oyun başlıyor. 0 ile 100 arasında bir sayı tutun.")
input("Tuttunuz mu? Hazır mısınız? (Herhangi bir tuşa basın)")

tahmin_edildi = False
tahmin_sayisi = 0
alt_sinir = 0
ust_sinir = 100

while not tahmin_edildi:
    tahmin = random.randint(alt_sinir, ust_sinir)
    print("Tahmin:", tahmin)
    geri_bildirim = input("Durum (Yukari / Asagi / Bildin): ")

    if geri_bildirim == "Yukari":
        alt_sinir = tahmin + 1
    elif geri_bildirim == "Asagi":
        ust_sinir = tahmin - 1
    elif geri_bildirim == "Bildin":
        tahmin_edildi = True

    tahmin_sayisi += 1

print("Tahmin edilen sayı:", tahmin)
print("Tahmin sayısı:", tahmin_sayisi)
# Out:
# Oyun başlıyor. 0 ile 100 arasında bir sayı tutun.
# Tahmin: 27
# Tahmin: 62
# Tahmin: 61
# Tahmin: 43
# Tahmin: 34
# Tahmin: 51
# Tahmin: 64
# Tahmin: 58
# Tahmin: 51
# Tahmin: 88
# Tahmin: 45
# Tahmin: 78
# Tahmin: 49
# Tahmin: 97
# Tahmin: 63
# Tahmin: 85
# Tahmin: 29
# Tahmin: 49
# Tahmin: 81
# Tahmin: 80
# Tahmin: 30
# Tahmin: 64
# Tahmin: 62
# Tahmin: 33
# Tahmin: 39
# Tahmin: 65
# Tahmin: 86
# Tahmin: 88
# Tahmin: 66
# Tahmin: 33
# Tahmin: 80
# Tahmin: 73
# Tahmin: 81
# Tahmin: 57
# Tahmin: 51
# Tahmin: 51
# Tahmin: 88
# Tahmin: 60
# Tahmin: 40
# Tahmin: 46
# Tahmin: 53

# %% [markdown]
# # Problem 8 Net Yaş Hesaplayıcı
#
# Kullanıcının bugünün güncel tarihine kadar yaşadığı ay, gün, yıl süresini hesaplayan bir Python kodu yazınız. (Her ay 30 gün kabul edilmeyecektir. Kodu yazarken hangi ayın kaç gün olduğuna [Şubat ayının 29 gün olduğu yıllar dahil] dikkat edin.)

# %%
# 8.Problemin Çözümünü Buraya Yazınız
from datetime import date

def net_yas_hesaplayici(gun, ay, yil):
    bugun = date.today()
    bugun_gun = bugun.day
    bugun_ay = bugun.month
    bugun_yil = bugun.year

    if ay > bugun_ay or (ay == bugun_ay and gun > bugun_gun):
        bugun_yil -= 1

    yas_yil = bugun_yil - yil
    yas_ay = bugun_ay - ay
    yas_gun = bugun_gun - gun

    if yas_gun < 0:
        yas_ay -= 1
        yas_gun += 30  # Her ayın ortalama 30 gün olduğunu varsaydık

    if yas_ay < 0:
        yas_yil -= 1
        yas_ay += 12

    return yas_yil, yas_ay, yas_gun

gun = int(input("Doğduğunuz günü girin: "))
ay = int(input("Doğduğunuz ayı girin: "))
yil = int(input("Doğduğunuz yılı girin: "))

net_yas = net_yas_hesaplayici(gun, ay, yil)
print("Net yaşınız: {} yıl, {} ay, {} gün".format(*net_yas))
# Out:
# Net yaşınız: 22 yıl, 6 ay, 3 gün

# %% [markdown]
# # Problem 9 Tek-Çift
#
# Kullanıcıdan 'q' tuşuna basana kadar rastgele sayılar alın. Tek olanları bir listeye, çift olanları bir başka listeye büyükten küçüğe sıralanacak şekilde atın. Listeleri ekrana yazdıran bir kod yazın.

# %%
# 9.Problemin Çözümünü Buraya Yazınız
tek_sayilar = []
cift_sayilar = []

while True:
    sayi = input("Bir sayı girin (Çıkmak için 'q' tuşuna basın): ")

    if sayi == 'q':
        break

    sayi = int(sayi)

    if sayi % 2 == 0:
        cift_sayilar.append(sayi)
    else:
        tek_sayilar.append(sayi)

tek_sayilar.sort(reverse=True)
cift_sayilar.sort(reverse=True)

print("Tek Sayılar:", tek_sayilar)
print("Çift Sayılar:", cift_sayilar)
# Out:
# Tek Sayılar: [15, 15]
# Çift Sayılar: [14, 12, 10]

# %% [markdown]
#  # Problem 10 Altıgen Çizimi
#
# Kullanıcıdan altıgenin kaç satırdan oluşacağı ve orta satırında kaç karakter olacağı bilgisini alarak '*' karakteri ile bir altıgen çizin. (For loop kullanabilirsiniz.)

# %%
# 10.Problemin Çözümünü Buraya Yazınız
satir_sayisi = int(input("Altıgenin kaç satırdan oluşmasını istersiniz? "))
orta_satir = int(input("Orta satırda kaç karakter olmasını istersiniz? "))


for i in range(1, satir_sayisi + 1):
    bosluk_sayisi = satir_sayisi - i
    print(" " * bosluk_sayisi + "*" * (2*i - 1))

print("*" * orta_satir)


for i in range(satir_sayisi, 0, -1):
    bosluk_sayisi = satir_sayisi - i
    print(" " * bosluk_sayisi + "*" * (2*i - 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
# ***
# *********
#  *******
#   *****
#    ***
#     *
